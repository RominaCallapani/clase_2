# %% [markdown]
# <a href="https://colab.research.google.com/github/RominaCallapani/clase_2/blob/main/TAREA2/CLASE_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagen1.png](data:image/png;base64,...)

# %% [markdown]
# 1. INTRODUCCION AL ENTORNO DE PYTHON

# %% [markdown]
# -Verificando la versión de Python

# %%
# !python3
# Out:
# Python 3.7.13 (default, Apr 24 2022, 01:04:09)
# [GCC 7.5.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>> credits
#     Thanks to CWI, CNRI, BeOpen.com, Zope Corporation and a cast of thousands
#     for supporting Python development.  See www.python.org for more information.
# >>>
#
# KeyboardInterrupt
# >>> ^C

# %% [markdown]
# -Ejecutando en Python

# %%
print("Hello Python interpreter")
# Out:
# Hello Python interpreter

# %% [markdown]
# -Variables en Python

# %%
message= "Hello Python world!"
print(message)
# Out:
# Hello Python world!

# %% [markdown]
# -Usando variables con strings

# %%
first_name= "Romina"
last_name= "Callapani"

full_name= f"{first_name} {last_name}"
print(full_name)
# Out:
# Romina Callapani

# %%
first_name= str(input('Ingrese el primer nombre:'))
last_name= str(input('Ingrese el apellido:'))

full_name= f"{first_name} {last_name}"
print(f"Bienvenida {full_name}!")
# Out:
# Ingrese el primer nombre:Romina
# Ingrese el apellido:Callapani
# Bienvenida Romina Callapani!

# %%
print(f"Hola, {full_name}!")
# Out:
# Hola, Romina Callapani!

# %%
message= f"Hola,{full_name}!"
print(message)
# Out:
# Hola,Romina Callapani!

# %%
print("Python")
# Out:
# Python

# %%
print("Python's")
# Out:
# Python's

# %%
print("\tPython")
# Out:
# 	Python

# %%
print("Languages:\nPython\nC\nJavaScript")
# Out:
# Languages:
# Python
# C
# JavaScript

# %%
print("Languages:\n\tPython\n\tC\n\tJavaScript")
# Out:
# Languages:
# 	Python
# 	C
# 	JavaScript

# %% [markdown]
# -Espacios en Python

# %%
favorite_language= 'python  '
favorite_language
# Out:
# 'python  '

# %%
favorite_language.rstrip()
# Out:
# 'python'

# %%
favorite_language= 'python  '
favorite_language = favorite_language.rstrip()
favorite_language
# Out:
# 'python'

# %%
favorite_language = ' python '
favorite_language
# Out:
# ' python '

# %%
favorite_language.rstrip()
# Out:
# ' python'

# %%
favorite_language.lstrip()
# Out:
# 'python '

# %%
favorite_language.strip()
# Out:
# 'python'

# %% [markdown]
# -Problemas comunes

# %%
message = " Mi libro 'El león, la bruja y el ropero' es mi favorito"
print(message)
# Out:
#  Mi libro 'El león, la bruja y el ropero' es mi favorito

# %%
message = 'One of Python's strengths is its diverse community.'
print(message)
# Out:
#   File "<ipython-input-23-a9250de55b39>", line 1
#     message = 'One of Python's strengths is its diverse community.'
#                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# -Números

# %%
2+3
# Out:
# 5

# %%
3**2
# Out:
# 9

# %%
(2+3)*4
# Out:
# 20

# %% [markdown]
# -Floats

# %%
0.1+0.1
# Out:
# 0.2

# %%
2 * 0.2
# Out:
# 0.4

# %%
0.2 + 0.1
# Out:
# 0.30000000000000004

# %% [markdown]
# -Enteros y floats

# %%
4/2
# Out:
# 2.0

# %%
1 + 2.0
# Out:
# 3.0

# %%
1*3.0
# Out:
# 3.0

# %% [markdown]
# -Guiones bajos en números

# %%
universe_age = 15_000_000_000
print(universe_age)
# Out:
# 15000000000

# %% [markdown]
# -Asignación Múltiple

# %%
a, b = 1, 2
b
# Out:
# 2

# %%
x, y, z = 0, 0, 0

# %%
y
# Out:
# 0

# %% [markdown]
# -Constantes

# %%
MAX_CONNECTIONS = 5000

# %% [markdown]
# **Ejercicio**

# %% [markdown]
# Usa una variable para representar un número. Luego, usando esa variable, cree un mensaje que revele su número. Imprime ese mensaje.

# %%
num= 20
print(f"El número es {num}")
# Out:
# El número es 20

# %% [markdown]
# -Comentarios

# %%
# Código para saludar.
print("Hola programadores de Python!")
# Out:
# Hola programadores de Python!

# %% [markdown]
# -El Zen de Python

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# Introducción a listas

# %%
a = ['John', 'Ricardo', 'Marcelo', 'Heidy', 'Nataly']
a
# Out:
# ['John', 'Ricardo', 'Marcelo', 'Heidy', 'Nataly']

# %%
type(a)
# Out:
# list

# %%
a = [1, 10, 4, 5, 99.0]
a
# Out:
# [1, 10, 4, 5, 99.0]

# %%
a = [1, 10, 4, 5, 'Nataly']
a
# Out:
# [1, 10, 4, 5, 'Nataly']

# %%
a = [1, 10, 4, 5, None]
a
# Out:
# [1, 10, 4, 5, None]

# %%
a = [1, 10, 4, 5, [2, 3, 8]]
a
# Out:
# [1, 10, 4, 5, [2, 3, 8]]

# %%
a[0]
# Out:
# 1

# %%
a[3]
# Out:
# 5

# %%
a[4][1]
# Out:
# 3
